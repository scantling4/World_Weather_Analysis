# %%
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
temps = [18.2, 24.5, 57.6, 76.5, 54.2, 30.1, 40.3, 55.2, 82.1]
daylight = [7.6, 9.2, 12.1, 13.4, 13.9, 14.2, 13.5, 11.8, 10.9]

# %%
plt.scatter(daylight,temps)
plt.xlabel('Hours of Daylight')
plt.ylabel('Average Monthly Temperature')
plt.show()

# %%
linregress(daylight,temps)
# Out:
# LinregressResult(slope=3.9294251874388806, intercept=2.202586113223923, rvalue=0.3987221864587962, pvalue=0.2877910944544869, stderr=3.4159611586657794)

# %%
(slope, intercept, rval, pval, stderr) = linregress(daylight,temps)

# %%
line_eq = "y = " +str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
# Out:
# y = 3.93x + 2.2

# %%
regress_values = [(day * slope + intercept) for day in daylight]

# %%
plt.scatter(daylight,temps)

# %%
plt.scatter(daylight,temps)
plt.plot(daylight,regress_values)
plt.xlabel('Hours of Daylight')
plt.ylabel('Average Monthly Temperature')
plt.show()
