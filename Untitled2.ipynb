# %%
import pandas as pd

# %%
rain_df = pd.read_csv("weather_data/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
import matplotlib.pyplot as plt
import numpy as np

x_axis = rain_df["State"]
y_axis = rain_df["Inches"]

# %%
# Create the plot
tick_locations = [value for value in rain_df["State"]]
plt.figure(figsize=(20,3))
plt.bar(rain_df["State"], rain_df["Inches"])

plt.xticks(tick_locations,rain_df["State"], rotation= 'vertical')

plt.title("Rain in Inches by State")
plt.xlabel("State")
plt.ylabel("Rain (inches)")
plt.show()

# %%
rain_df.mode().count()
# Out:
# State           50
# Inches           3
# Milli­metres     1
# Rank             1
# dtype: int64

# %%
rain_df.sort_values(['Rank'], ascending=True).head()
# Out:
#           State  Inches  Milli­metres  Rank
# 10       Hawaii    63.7          1618     1
# 17    Louisiana    60.1          1528     2
# 23  Mississippi    59.0          1499     3
# 0       Alabama    58.3          1480     4
# 8       Florida    54.5          1385     5

# %%
rain_df.columns
# Out:
# Index(['State', 'Inches', 'Milli­metres', 'Rank'], dtype='object')

# %%
import requests
url = "https://api.spacexdata.com/v2/launchpads"
print(url)
# Out:
# https://api.spacexdata.com/v2/launchpads

# %%
city_weather = requests.get(url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the JSON text of the 'Get' request.
a_json_object= city_weather.json()

# %%
print(a_json_object)
# Out:
# [{'padid': 5, 'id': 'vafb_slc_3w', 'name': 'VAFB SLC 3W', 'full_name': 'Vandenberg Air Force Base Space Launch Complex 3W', 'status': 'retired', 'location': {'name': 'Vandenberg Air Force Base', 'region': 'California', 'latitude': 34.6440904, 'longitude': -120.5931438}, 'vehicles_launched': ['Falcon 1'], 'attempted_launches': 0, 'successful_launches': 0, 'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3', 'details': 'SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.'}, {'padid': 2, 'id': 'ccafs_slc_40', 'name': 'CCAFS SLC 40', 'full_name': 'Cape Canaveral Air Force Station Space Launch Complex 40', 'status': 'active', 'location': {'name': 'Cape Canaveral', 'region': 'Florida', 'latitude': 28.5618571, 'longitude': -80.577366}, 'vehicles_launched': ['Falcon 9'], 'attempted_launches': 59, 'successful_launches': 57, 'wikipedia': 'https://en.wikipedia.org/wi
# ...

# %%
length = len(a_json_object)

# %%
print(length)
# Out:
# 6

# %%
test_grades = {
    'Class': ['Oct', 'Oct', 'Jan', 'Jan', 'Oct', 'Jan'], 
    'Name': ["Cyndy", "Logan", "Laci", "Elmer", "Crystle", "Emmie"], 
    'Test Score': [90, 59, 72, 88, 98, 60]}

# %%
test_grades_df = pd.DataFrame(test_grades)

# %%
test_grades_df
# Out:
#   Class     Name  Test Score
# 0   Oct    Cyndy          90
# 1   Oct    Logan          59
# 2   Jan     Laci          72
# 3   Jan    Elmer          88
# 4   Oct  Crystle          98
# 5   Jan    Emmie          60

# %%
test_score = test_grdes_df["Test Score"].value_counts()
test_score
# Out:
# 98    1
# 88    1
# 60    1
# 59    1
# 90    1
# 72    1
# Name: Test Score, dtype: int64

# %%
bins = [0, 59, 69, 79, 89, 100]
test_grades_df.groupby(pd.cut(test_score, bins)).count()
letter_grades = ["<$58", "$59-69", "$70-89", "$90-99"]

# Categorize spending based on the bins.
#test_grades_df['Letter Grade']= pd.cut(test_grades_df['Test Score'], bins, labels= letter_grades)

# %%
test_grades_df['Letter Grade']= pd.cut(test_grades_df['Test Score'], bins,labels=letter_grades)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-8cedee94451d> in <module>
# ----> 1 test_grades_df['Letter Grade']= pd.cut(test_grades_df['Test Score'], bins,labels=letter_grades)
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     263         include_lowest=include_lowest,
#     264         dtype=dtype,
# --> 265         duplicates=duplicates,
#     266     )
#     267
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     409             if len(labels) != len(bins) - 1:
#     410                 raise ValueError(
# --> 411                     "Bin labels must be one fewer than the number of bin edges"
# ...

# %%
import requests
url = "https://api.spacexdata.com/v2/launchpads"
print(url)
# Out:
# https://api.spacexdata.com/v2/launchpads

# %%
space = requests.get(url)
space.json()
# Out:
# [{'padid': 5,
#   'id': 'vafb_slc_3w',
#   'name': 'VAFB SLC 3W',
#   'full_name': 'Vandenberg Air Force Base Space Launch Complex 3W',
#   'status': 'retired',
#   'location': {'name': 'Vandenberg Air Force Base',
#    'region': 'California',
#    'latitude': 34.6440904,
#    'longitude': -120.5931438},
#   'vehicles_launched': ['Falcon 1'],
#   'attempted_launches': 0,
#   'successful_launches': 0,
#   'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3',
#   'details': 'SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.'},
#  {'padid': 2,
#   'id': 'ccafs_slc_40',
#   'name': 'CCAFS SLC 40',
#   'full_name': 'Cape Canaveral Air Force Station Space Launch Complex 40',
#   'status': 'active',
#   'location': {'name': 'Cape Canaveral',
#    'region': 'Florida',
#    'latitude': 28.5618571,
#    'longitude': -80.577366},
# ...

# %%
luh = space.json()
luh
# Out:
# [{'padid': 5,
#   'id': 'vafb_slc_3w',
#   'name': 'VAFB SLC 3W',
#   'full_name': 'Vandenberg Air Force Base Space Launch Complex 3W',
#   'status': 'retired',
#   'location': {'name': 'Vandenberg Air Force Base',
#    'region': 'California',
#    'latitude': 34.6440904,
#    'longitude': -120.5931438},
#   'vehicles_launched': ['Falcon 1'],
#   'attempted_launches': 0,
#   'successful_launches': 0,
#   'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3',
#   'details': 'SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.'},
#  {'padid': 2,
#   'id': 'ccafs_slc_40',
#   'name': 'CCAFS SLC 40',
#   'full_name': 'Cape Canaveral Air Force Station Space Launch Complex 40',
#   'status': 'active',
#   'location': {'name': 'Cape Canaveral',
#    'region': 'Florida',
#    'latitude': 28.5618571,
#    'longitude': -80.577366},
# ...

# %%
city_data= []
record_count = 1
set_count = 1

for i in range(len(full_name)):
# Out:
#   File "<ipython-input-110-d59553f85e2a>", line 5
#     for i in range(len(full_name)):
#                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
to_find = input ("to find")
luh["full_name"]

for i in range(len(luh)):
    if luh[i]["full_name"] == to_find:
        print(luh[i]["full_name"])
# Out:
# to finder
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-956e7e25cc8e> in <module>
#       1 to_find = input ("to find")
# ----> 2 luh["full_name"]
#       3
#       4 for i in range(len(luh)):
#       5     if luh[i]["full_name"] == to_find:
#
# TypeError: list indices must be integers or slices, not str

# %%
print("I think her name was + " + name + "?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc4e8e0642ed> in <module>
# ----> 1 print("I think her name was + " + name + "?")
#
# NameError: name 'name' is not defined

# %%
print("Your name is a nonsense number. Look: " + int("Gabriel"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-3dc196b6b737> in <module>
# ----> 1 print("Your name is a nonsense number. Look: " + int("Gabriel"))
#
# ValueError: invalid literal for int() with base 10: 'Gabriel'

# %%
print("Infinity looks like + " + str(10 / 0) + ".")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-115-03d7faee3ae3> in <module>
# ----> 1 print("Infinity looks like + " + str(10 / 0) + ".")
#
# ZeroDivisionError: division by zero

# %%
print("I think her name was + " + name + "?")
# Out:
# I think her name was + Karen?

# %%
students = ("Frank", "Mary", "Jasmine", "Ivana", "Ahmed")
students.append("Serena")
print(students)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-72be960c98fd> in <module>
#       1 students = ("Frank", "Mary", "Jasmine", "Ivana", "Ahmed")
# ----> 2 students.append("Serena")
#       3 print(students)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
import pandas as pd

# %%
cereal_df = pd.read_csv("weather_data/cereal.csv")
cereal_df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
with open(cereal_df, newline="") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-82d2ecf243d7> in <module>
# ----> 1 with open(cereal_csv, newline="") as csvfile:
#       2     csvreader = csv.reader(csvfile, delimiter=",")
#
# NameError: name 'cereal_csv' is not defined

# %%
import pandas as pd

# %%
donors_df = pd.read_csv("weather_data/donors2008.csv")
donors_df.head()
# Out:
#   LastName FirstName          Employer      City State    Zip  Amount  FIELD8
# 0    Aaron    Eugene  State Department    Dulles    VA  20189   500.0     NaN
# 1    Abadi   Barbara       Abadi & Co.  New York    NY  10021   200.0     NaN
# 2  Adamany   Anthony           Retired  Rockford    IL  61103   500.0     NaN
# 3    Adams  Lorraine              Self  New York    NY  10026   200.0     NaN
# 4    Adams    Marion              None    Exeter    NH  03833   100.0     NaN

# %%
average_amount = donors_df.groupby(["State"]).mean()["Amount"]
average_amount
# Out:
# State
# AE     100.000000
# AK     175.000000
# AL     212.500000
# AP     200.000000
# AR     350.000000
# AZ     206.000000
# CA     685.234973
# CO     851.250000
# CT     825.714286
# DC     647.115385
# DE     190.000000
# FL     709.358974
# GA     842.307692
# HI     195.454545
# IA     600.000000
# ID     341.666667
# IL    1114.519231
# IN     225.000000
# KS     283.333333
# KY     735.000000
# LA     158.333333
# MA     750.714286
# MD     819.823529
# ME     211.111111
# MI     241.666667
# MN     697.000000
# MO     463.888889
# MS    1208.333333
# MT     200.000000
# NC     440.625000
# NE     183.333333
# NH     368.750000
# NJ     276.111111
# NM     298.913043
# NV     393.333333
# NY     910.829146
# OH     501.562500
# OK     200.000000
# OR     321.052632
# PA     896.755556
# QC     250.000000
# RI     700.000000
# SC     287.500000
# TN     257.142857
# TX     485.193182
# UT     200.000000
# VA     701.093465
# VI     225.000000
# VT     350.000000
# ...

# %%
greater = average_amount >= 750
greater.sum()
# Out:
# 9
